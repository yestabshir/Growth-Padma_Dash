# %%
import pandas as pd

# %% [markdown]
# ### Loading Files

# %%
act = pd.read_excel(r'C:\Users\yesta\OneDrive\Documents\Datas Office\Weekly CS Update\Data\A1.xlsx')
print(act)
# Out:
#          company_name old_user_login old_user_email old_post_title  cookie_id  \
# 0               Pleaz            NaN            NaN            NaN       13.0
# 1                 NaN            NaN            NaN            NaN    14890.0
# 2           Milestone            NaN            NaN            NaN    14943.0
# 3      Dansk Standard            NaN            NaN            NaN    13858.0
# 4      Dansk Standard            NaN            NaN            NaN    13858.0
# ...               ...            ...            ...            ...        ...
# 43221          Nestle            NaN            NaN            NaN    12613.0
# 43222           Pleaz            NaN            NaN            NaN    13574.0
# 43223          Nestle            NaN            NaN            NaN     6533.0
# 43224    LearningBank            NaN            NaN            NaN    14169.0
# 43225          Nestle            NaN            NaN            NaN    14654.0
#
# ...

# %%
df.head()
# Out:
#      company_name old_user_login old_user_email old_post_title  cookie_id  \
# 0           Pleaz            NaN            NaN            NaN       13.0
# 1             NaN            NaN            NaN            NaN    14890.0
# 2       Milestone            NaN            NaN            NaN    14943.0
# 3  Dansk Standard            NaN            NaN            NaN    13858.0
# 4  Dansk Standard            NaN            NaN            NaN    13858.0
#
#       user_login           user_email  no_of_participate  country  \
# 0          admin  mickikn@hotmail.com                 15  Denmark
# 1  sthb@seges.dk        sthb@seges.dk                  3  Denmark
# 2      milestone    mnie@milestone.dk                  3  Denmark
# 3  Danskstandard      clu@ecolabel.dk                  8  Denmark
# 4  Danskstandard      clu@ecolabel.dk                  8  Denmark
#
#                         post_title          video_date          video_time  \
# ...

# %%
df = df.drop('company_branch', axis=1)

# %%
df = df.drop('company_region', axis=1)

# %%
df = df.drop('old_user_login', axis=1)

# %%
df = df.drop('old_user_email', axis=1)

# %%
df = df.drop('old_post_title', axis=1)

# %%
df.head()
# Out:
#      company_name  cookie_id     user_login           user_email  \
# 0           Pleaz       13.0          admin  mickikn@hotmail.com
# 1             NaN    14890.0  sthb@seges.dk        sthb@seges.dk
# 2       Milestone    14943.0      milestone    mnie@milestone.dk
# 3  Dansk Standard    13858.0  Danskstandard      clu@ecolabel.dk
# 4  Dansk Standard    13858.0  Danskstandard      clu@ecolabel.dk
#
#    no_of_participate  country                       post_title  \
# 0                 15  Denmark                     Affirmations
# 1                  3  Denmark                  StrÃ¦k i Hoften
# 2                  3  Denmark                Computer Back 3.0
# 3                  8  Denmark                       Mouse Arms
# 4                  8  Denmark  Computer Back and Shoulders 3.0
#
#            video_date          video_time  \
# 0 2022-09-19 09:51:33 2022-09-19 09:51:33
# 1 2022-09-19 09:48:43 2022-09-19 09:48:43
# 2 2022-09-19 09:45:56 2022-09-19 09:45:56
# ...

# %% [markdown]
# ### Dropping NAN Values

# %%
df=df.dropna()
print(df)
# Out:
#          company_name  cookie_id     user_login                 user_email  \
# 0               Pleaz       13.0          admin        mickikn@hotmail.com
# 2           Milestone    14943.0      milestone          mnie@milestone.dk
# 3      Dansk Standard    13858.0  Danskstandard            clu@ecolabel.dk
# 4      Dansk Standard    13858.0  Danskstandard            clu@ecolabel.dk
# 5               pleaz    14942.0  hjfa@pleaz.io              hjfa@pleaz.io
# ...               ...        ...            ...                        ...
# 39100        L'OrÃ©al        0.0         loreal  Susanne.LARSEN@loreal.com
# 39101        L'OrÃ©al        0.0         loreal  Susanne.LARSEN@loreal.com
# 39102        L'OrÃ©al        0.0         loreal  Susanne.LARSEN@loreal.com
# 39103           Pleaz        0.0       insights           hello@pleaz.work
# 39104           Pleaz        0.0       insights           hello@pleaz.work
#
# ...

# %%
df.head()
# Out:
#      company_name  cookie_id     user_login           user_email  \
# 0           Pleaz       13.0          admin  mickikn@hotmail.com
# 2       Milestone    14943.0      milestone    mnie@milestone.dk
# 3  Dansk Standard    13858.0  Danskstandard      clu@ecolabel.dk
# 4  Dansk Standard    13858.0  Danskstandard      clu@ecolabel.dk
# 5           pleaz    14942.0  hjfa@pleaz.io        hjfa@pleaz.io
#
#    no_of_participate  country                       post_title  \
# 0                 15  Denmark                     Affirmations
# 2                  3  Denmark                Computer Back 3.0
# 3                  8  Denmark                       Mouse Arms
# 4                  8  Denmark  Computer Back and Shoulders 3.0
# 5                  1  Denmark                  Strong Core 2.0
#
#            video_date          video_time  \
# 0 2022-09-19 09:51:33 2022-09-19 09:51:33
# 2 2022-09-19 09:45:56 2022-09-19 09:45:56
# 3 2022-09-19 09:38:43 2022-09-19 09:38:43
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
get_ipython().run_line_magic('matplotlib', 'inline')
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.tools as tls
import plotly.express as px
import numpy as np
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import matplotlib.pyplot as plt

# %%
df.plot.scatter(x='company_name', y='no_of_participate')
# Out:
# <AxesSubplot:xlabel='company_name', ylabel='no_of_participate'>
